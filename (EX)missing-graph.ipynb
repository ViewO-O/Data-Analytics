# %% [markdown]
# # missing Graph (EX)

# %% [markdown]
# #### 1. ตรวจสอบว่ามีข้อมูลแถวไหนบ้างที่มีค่า missing และแสดงผลออกมา
# #### 2. จากคําตอบในข้อ 2 ให้เปลี่ยนค่า missing ที่อยู่ใน column name PoolQC ด้วย 9 และแสดงผลออกมา
# #### 3. จากคําตอบในข้อ 2 ให้เปลี่ยนค่า missing -ของ LotFrontage ด้วยค่าเฉลี่ยของ LotFrontage และแสดงผลออกมา
#
# #### 4 ใช้matplotlib เพื้อสร้าง histogram ที่สแดง SalePrice เป็น 10 สีของ histogram เป็นสีเหลือง ขอบของ histogram เป็นแดง
#
# #### 5. ใช้seaborn เพื่อสร้าง scatter plot ระหว่าง GrLivArea, SalePrice
#
# #### 6. สร้างกราฟวงกลมที่แสดงความสัมพันธ์ระหว่าง (HouseStyle) กับ HousePrice
#
# #### 7. ใช้seabornเพื่อสร้าง histogram ที่แสดงข้อมูล Saleprice เป็น 10 ช่วง สีของ histogram เป็นเขียวและขอบของ histogram สีม่วง
#
# #### 8. ใช้ seabon เพื่อสร้าง linear regression่plot ระหว่าง GrLivArea, SalePr่ce
#
# #### 9. หาค่าสถิติพื้นฐานของ LotArea
#
# #### 10. plot boxplot ของ LotArea
#
#
# ง LotArea
# อง LotArea

# %%
#Import Python Libraries
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
house = pd.read_csv("C:/Users/User/Desktop/DA/05-Exercise-LAB-22Aug2024/housing.csv")

# %%
house.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#1
house[house.isnull().any(axis=1)].head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#2
house['PoolQC'].fillna(9)
# Out:
# 0       9
# 1       9
# 2       9
# 3       9
# 4       9
#        ..
# 1455    9
# 1456    9
# 1457    9
# 1458    9
# 1459    9
# Name: PoolQC, Length: 1460, dtype: object

# %%
#3
mean = house['LotFrontage'].mean()
house['LotFrontage'].fillna(mean)
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
#4
#Show graphs withint Python notebook
# %matplotlib inline

# %%
plt.hist(house['SalePrice'],bins=10, color = 'yellow', edgecolor = 'red')
# Out:
# (array([148., 723., 373., 135.,  51.,  19.,   4.,   3.,   2.,   2.]),
#  array([ 34900., 106910., 178920., 250930., 322940., 394950., 466960.,
#         538970., 610980., 682990., 755000.]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(house['GrLivArea'], house['SalePrice'], color = "red")

# %%
house.groupby(['HouseStyle'])['SalePrice'].count().plot(kind='pie')
# Out:
# <Axes: ylabel='SalePrice'>

# %%
#sns.histplot(house['SalePrice'],bins = 10, color='green',edgecolor='purple',kde=True)
sns.histplot(house['SalePrice'],bins = 10, color='green',edgecolor='purple')
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
sns.regplot(x='GrLivArea', y='SalePrice', data=house)
# Out:
# <Axes: xlabel='GrLivArea', ylabel='SalePrice'>

# %%
house.LotArea.describe()
# Out:
# count      1460.000000
# mean      10516.828082
# std        9981.264932
# min        1300.000000
# 25%        7553.500000
# 50%        9478.500000
# 75%       11601.500000
# max      215245.000000
# Name: LotArea, dtype: float64

# %%
sns.boxplot(x='LotArea',data=house) #แนวตั้ง
# Out:
# <Axes: xlabel='LotArea'>

# %%
sns.boxplot(y='LotArea',data=house) #แนวน
# Out:
# <Axes: ylabel='LotArea'>
